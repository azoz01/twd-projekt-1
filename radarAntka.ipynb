# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('data/Ramka_ghg_lang_freshwater.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     6 non-null      object
#  1   land        6 non-null      float64
#  2   ghg         6 non-null      float64
#  3   freshwater  6 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 320.0+ bytes

# %%
from math import pi

# Set data
df = pd.DataFrame({
    'var1': [38, 1.5, 30, 4],
    'var2': [29, 10, 9, 34],
    'var3': [8, 39, 23, 24],
    'var4': [7, 31, 33, 14],
    'var5': [28, 15, 32, 14]
})

def spider(df):
    categories=list(df)
    N = len(categories)

    # We are going to plot the first line of the data frame.
    # But we need to repeat the first value to close the circular graph:
    values=df.loc[0].values.flatten().tolist()
    values += values[:1]
    
    #values2=df.loc[1].values.flatten().tolist()
    #values2 += values2[:1]
    
    #values3=df.loc[2].values.flatten().tolist()
    #values3 += values3[:1]
    
    
    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
    plt.figure(figsize=(20,10))
    # Initialise the spider plot
    ax = plt.subplot(111, polar=True)

    # Draw one axe per variable + add labels
    #ax.set_rlabel_position(1000)
    plt.xticks(angles[:-1], categories, color='grey', size=20)

    XTICKS = ax.xaxis.get_major_ticks()
    for tick in XTICKS:
        tick.set_pad(70)
# Draw ylabels
    #ax.set_rlabel_position(0)
    plt.yticks([25, 50, 75, 100], ["25", "50", "75", "100"], color="grey", size=20)
    plt.ylim(0,120)

    # Plot data
    ax.plot(angles, values, linewidth=3, linestyle='solid')
    ax.fill(angles, values, 'b', alpha=0.1)
    #ax.plot(angles, values2, linewidth=3, linestyle='solid')
    #ax.fill(angles, values2, 'r', alpha=0.1)
    #ax.plot(angles, values3, linewidth=3, linestyle='solid')
    #ax.fill(angles, values3, 'g', alpha=0.1)
    #plt.title(country, size = 40)
    # Show the graph
    plt.show()


arr = df1.values.transpose()
max_rows = [max(i) for i in arr]
for j in range(3):
    for i in range(6):
        arr[j+1][i] /= max_rows[j+1]*0.01
df2 = pd.DataFrame(data=arr[1:,0:],        
              columns=arr[0,:])  

df2 = df2.iloc[:,[0,2,3,5,1,4]]

for i in range(3):
    spider(df2.iloc[[i],:].reset_index(drop = True))
df2
# Out:
#   Beef (beef herd) Lamb & Mutton   Pig Meat Tofu (soybeans) Fish (farmed)  \
# 0            100.0     97.630332   6.078791        1.087023      3.931953
# 1            100.0     34.385619  14.134714        3.199961     20.896314
# 2        15.574966     16.662907  22.015195        1.606616     60.421122
#
#   Prawns (farmed)
# 0        2.413152
# 1       71.590816
# 2           100.0

# %%
df2 = df1[((df1.Item == 'Meat')|
                 (df1.Item == 'Fruits - Excluding Wine')|
                 (df1.Item == 'Vegetables')|
                 (df1.Item == 'Wheat and products')|
                 (df1.Item == 'Rice (Milled Equivalent)'))]
df2
# Out:
#                            Area         Unit Element  \
# 9034                      India  1000 tonnes    Food
# 9036                      India  1000 tonnes    Food
# 9151                      India  1000 tonnes    Food
# 9152                      India  1000 tonnes    Food
# 9156                      India  1000 tonnes    Food
# 10072                     Japan  1000 tonnes    Food
# 10074                     Japan  1000 tonnes    Food
# 10199                     Japan  1000 tonnes    Food
# 10200                     Japan  1000 tonnes    Food
# 10204                     Japan  1000 tonnes    Food
# 14466                    Norway  1000 tonnes    Food
# 14468                    Norway  1000 tonnes    Food
# 14588                    Norway  1000 tonnes    Food
# 14589                    Norway  1000 tonnes    Food
# 14593                    Norway  1000 tonnes    Food
# 16958                   Senegal  1000 tonnes    Food
# 16959                   Senegal  1000 tonnes    Food
# ...

# %%
countries = people_in_thousands2013.keys()
for country in countries:
    df_test = df2[df2.Area == country]

    df_test = pd.DataFrame(df_test.values[:,[3,6,7]].transpose()[:,[2,3,0,4,1]])
    df_test.columns = df_test.iloc[0]

    df_test = df_test[1:].reset_index().drop('index', axis =1)

    spider(df_test, country).savefig('./plots/radar_plots/'+country+'.png', bbox_inches='tight')
    #df_test
